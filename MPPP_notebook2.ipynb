# %% [markdown]
# # MPPP Processing
#
# An Image object represents an image, processing would be done using the image array amd metadata stored as attributes in the image object. If the image is processed, the processed array could be accessed throught the attribute ```.im8``` of the image object.
#
#
# An ImProcessor represents and image processor object. It is initiated by providing it with a json config file. An example file could be found in ```./params/image_processing_config.json```. To process a list of images, use the function ```process_images()```.

# %%
from src2.Image import Image, Frame
from src2.ImProcessor import ImProcessor

# %%
# import glob

# # filter the images you want
# directory_input  =  './data'
# directory_output =  './res'

# sol = '709'

# pre = '*_'+str(sol)+'*_0'
# suf = 'refs_'+str(sol)


# sequ_id = ''
# index   = ''

# path_input     = directory_input
# IMG_paths      = [] 
# IMG_paths     += sorted( glob.glob(  directory_input + '/' +pre+'*_N*'+sequ_id+'*'+index+'.IMG' ) ) 
# IMG_paths     += sorted( glob.glob(  directory_input + '/*/ids/rdr/*/' +pre+'*_N*'+sequ_id+'*'+index+'.IMG' ) ) 

# if 'F_' in pre or 'V' in pre or 'M' in pre: 
#     IMG_paths += sorted( glob.glob(  directory_input + '/datadrive/*/ids/rdr/*/' +pre+'*_N*'+sequ_id+'*.IMG' ) ) 
#     IMG_paths += sorted( glob.glob(  directory_input + '/datadrive/' +pre+'*_N*'+sequ_id+'*.IMG' ) ) 
# if 'Z' in pre: 
#     IMG_paths += sorted( glob.glob(  directory_input + '/zcam/' +pre+'*_N*'+sequ_id+'*.IMG' ) ) 
#     IMG_paths += sorted( glob.glob(  directory_input + '/zcam/*/' +pre+'*_N*'+sequ_id+'*.IMG' ) ) 

# IMG_paths = IMG_paths[:]

# print( len(IMG_paths), 'images\n')
# Out:
# 0 images

# %% [markdown]
# First initialise a processor object by passing in a file path to the json config file for the processor. This config file should specify the file_extension, boolean flags for saving the different components, lower bound clip values and scales used.

# %%
# create a processor object
processor = ImProcessor("./params/image_processing_config.json")

# %% [markdown]
# To process all the images, provide a list of file paths, the output directory to save the processed images and the suffix to be used in naming the output csv file

# %%
IMG_paths = ["./data/ZL0_0709_0729888971_069RAD_N0332864ZCAM07114_0340LMA01.IMG",
            "./data/ZL0_0709_0729889008_069RAD_N0332864ZCAM07114_1100LMA01.IMG",
            "./data/ZL0_0711_0730054378_178RAD_N0332864ZCAM03554_1100LMA03.IMG",
            "./data/ZL0_0711_0730054943_723RAD_N0332864ZCAM03014_048085A02.IMG",
            "./data/ZL0_0711_0730060145_020RAD_N0332864ZCAM03552_0630LMA01.IMG",
            "./data/ZL0_0711_0730060638_443RAD_N0332864ZCAM03014_048085A01.IMG",
            "./data/ZL0_0711_0730064703_098RAD_N0332864ZCAM03553_1100LMA01.IMG",
            "./data/ZL0_0711_0730065319_303RAD_N0332864ZCAM03014_048085A01.IMG",
            "./data/ZR0_0709_0729888971_069RAD_N0332864ZCAM07114_0340LMA01.IMG",
            "./data/ZR0_0709_0729889008_069RAD_N0332864ZCAM07114_1100LMA01.IMG",
            "./data/ZR0_0711_0730054569_178RAD_N0332864ZCAM03554_1100LMA03.IMG",
            "./data/ZR0_0711_0730054943_723RAD_N0332864ZCAM03014_048085A02.IMG",
            "./data/ZR0_0711_0730060314_988RAD_N0332864ZCAM03552_0630LMA01.IMG",
            "./data/ZR0_0711_0730060638_443RAD_N0332864ZCAM03014_048085A01.IMG",
            "./data/ZR0_0711_0730064931_081RAD_N0332864ZCAM03553_1100LMA01.IMG"]

processor.process_images(img_paths = IMG_paths,
                        output_dir = "./res",
                        suf = suf,
                        find_offset_mode=True,
                        frame = Frame.SITE,
                        angles = 'opk',
                        save_im = True)
# Out:
# Number of images: 15
# ./data/ZL0_0709_0729888971_069RAD_N0332864ZCAM07114_0340LMA01.IMG
# True
# 0 opened ZL0_0709_0729888971_069RAD_N0332864ZCAM07114_0340LMA01.IMG
# saved ./res/sols_0700-0799_sci/ZL0_0709_0729888971_069RAD_N0332864ZCAM07114_0340LMA01.png
# ./data/ZL0_0709_0729889008_069RAD_N0332864ZCAM07114_1100LMA01.IMG
# True
# 1 opened ZL0_0709_0729889008_069RAD_N0332864ZCAM07114_1100LMA01.IMG
# saved ./res/sols_0700-0799_sci/ZL0_0709_0729889008_069RAD_N0332864ZCAM07114_1100LMA01.png
# ./data/ZL0_0711_0730054378_178RAD_N0332864ZCAM03554_1100LMA03.IMG
# True
# 2 opened ZL0_0711_0730054378_178RAD_N0332864ZCAM03554_1100LMA03.IMG
# saved ./res/sols_0700-0799_sci/ZL0_0711_0730054378_178RAD_N0332864ZCAM03554_1100LMA03.png
# ./data/ZL0_0711_0730054943_723RAD_N0332864ZCAM03014_048085A02.IMG
# True
# 3 opened ZL0_0711_0730054943_723RAD_N0332864ZCAM03014_048085A02.IMG
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 17
#       1 IMG_paths = ["./data/ZL0_0709_0729888971_069RAD_N0332864ZCAM07114_0340LMA01.IMG",
#       2             "./data/ZL0_0709_0729889008_069RAD_N0332864ZCAM07114_1100LMA01.IMG",
#       3             "./data/ZL0_0711_0730054378_178RAD_N0332864ZCAM03554_1100LMA03.IMG",
#    (...)
#      14             "./data/ZR0_0711_0730060638_443RAD_N0332864ZCAM03014_048085A01.IMG",
#      15             "./data/ZR0_0711_0730064931_081RAD_N0332864ZCAM03553_1100LMA01.IMG"]
# ---> 17 processor.process_images(img_paths = IMG_paths,
#      18                         output_dir = "./res",
#      19                         suf = suf,
#      20                         find_offset_mode=True,
#      21                         frame = Frame.SITE,
#      22                         angles = 'opk',
#      23                         save_im = True)
#
# File c:\Users\ongyi\compasse\Calibration\MPPP\src2\ImProcessor.py:132, in ImProcessor.process_images(self, img_paths, output_dir, suf, find_offset_mode, frame, angles, save_im)
#     130 # process and save image
#     131 if img.save_im:
# --> 132     img = self.process_image(img, img.scale, img.scale_red,
#     133                              img.scale_blue, img.clip_low, img.gamma)
#     134     if img.save_mask:
#     135         img.im8a = cv2.cvtColor(img.im8, cv2.COLOR_BGR2RGBA)
#
# File c:\Users\ongyi\compasse\Calibration\MPPP\src2\ImProcessor.py:226, in ImProcessor.process_image(self, image, scale, scale_red, scale_blue, clip_low, gamma)
#     223 image.mask_image = mask_image
#     225 # apply color and brightness correction
# --> 226 image.proc_image = self._color_brightness_correction(
#     227     image.proc_image, ftau, scale, scale_red, scale_blue)
#     229 if image.filename[:3] == 'HNM':
#     230     im_max = np.percentile(image.proc_image, 99.9) * 1.01
#
# KeyboardInterrupt:

# %%
from planetaryimage import PDS3Image

label = PDS3Image.open(IMG_paths[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\ongyi\anaconda3\envs\MPPP\lib\site-packages\pvl\lexer.py:429, in lexer(s, g, d)
#     428     yield None
# --> 429     t = yield t
#     430 lexeme = ""
#
# ValueError: Expecting an Aggregation Block, an Assignment Statement, or an End Statement, but found ","
#
# During handling of the above exception, another exception occurred:
#
# LexerError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 from planetaryimage import PDS3Image
# ----> 3 PDS3Image.open(IMG_paths[0])
#
# File c:\Users\ongyi\anaconda3\envs\MPPP\lib\site-packages\planetaryimage\image.py:37, in PlanetaryImage.open(cls, filename)
#      35 else:
#      36     with open(filename, 'rb') as fp:
# ---> 37         return cls(fp, filename)
#
# File c:\Users\ongyi\anaconda3\envs\MPPP\lib\site-packages\planetaryimage\image.py:74, in PlanetaryImage.__init__(self, stream_string_or_array, filename, compression)
#      70 self.compression = compression
#      72 # TODO: rename to header and add footer?
#      73 #: The parsed label header in dictionary form.
# ---> 74 self.label = self._load_label(stream_string_or_array)
#      76 #: A numpy array representing the image
#      77 self.data = self._load_data(stream_string_or_array)
#
# File c:\Users\ongyi\anaconda3\envs\MPPP\lib\site-packages\planetaryimage\image.py:155, in PlanetaryImage._load_label(self, stream)
#     154 def _load_label(self, stream):
# --> 155     return pvl.load(stream)
#
# File c:\Users\ongyi\anaconda3\envs\MPPP\lib\site-packages\pvl\__init__.py:70, in load(path, parser, grammar, decoder, encoding, **kwargs)
#      41 def load(
#      42         path,
#      43         parser=None,
#    (...)
#      47         **kwargs
#      48 ):
#      49     """Returns a Python object from parsing the file at *path*.
#      50
#      51     :param path: an :class:`os.PathLike` which presumably has a
#    (...)
#      68     decodable text.
#      69     """
# ---> 70     return loads(
#      71         get_text_from(path, encoding=encoding),
#      72         parser=parser,
#      73         grammar=grammar,
#      74         decoder=decoder,
#      75         **kwargs
#      76     )
#
# File c:\Users\ongyi\anaconda3\envs\MPPP\lib\site-packages\pvl\__init__.py:213, in loads(s, parser, grammar, decoder, **kwargs)
#     210 elif not isinstance(parser, PVLParser):
#     211     raise TypeError("The parser must be an instance of pvl.PVLParser.")
# --> 213 return parser.parse(s)
#
# File c:\Users\ongyi\anaconda3\envs\MPPP\lib\site-packages\pvl\parser.py:858, in OmniParser.parse(self, s)
#     855 nodash = re.sub(r"-[\n\r\f]\s*", "", s)
#     856 self.doc = nodash
# --> 858 return super().parse(nodash)
#
# File c:\Users\ongyi\anaconda3\envs\MPPP\lib\site-packages\pvl\parser.py:207, in PVLParser.parse(self, s)
#     205 self.doc = s
#     206 tokens = self.lexer(s, g=self.grammar, d=self.decoder)
# --> 207 module = self.parse_module(tokens)
#     208 module.errors = sorted(self.errors)
#     209 return module
#
# File c:\Users\ongyi\anaconda3\envs\MPPP\lib\site-packages\pvl\parser.py:278, in PVLParser.parse_module(self, tokens)
#     276 # print(f'got to bottom: {m}')
#     277 t = next(tokens)
# --> 278 tokens.throw(
#     279     ValueError,
#     280     "Expecting an Aggregation Block, an Assignment "
#     281     "Statement, or an End Statement, but found "
#     282     f'"{t}" ',
#     283 )
#
# File c:\Users\ongyi\anaconda3\envs\MPPP\lib\site-packages\pvl\lexer.py:435, in lexer(s, g, d)
#     432         continue
#     434 except ValueError as err:
# --> 435     raise LexerError(err, s, i, lexeme)
#
# LexerError: (LexerError(...), 'Expecting an Aggregation Block, an Assignment Statement, or an End Statement, but found "," : line 1 column 5 (char 4) near ""')
